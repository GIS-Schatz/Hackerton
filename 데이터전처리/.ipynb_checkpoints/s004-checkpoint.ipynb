# %% [markdown]
# # 아이템 기반 협업필터링

# %%
# 헙업 필터링 -  다른유저의 정보를 사용한다
# 최근접 이웃 협업 필터링 knn
#     사용자기반
#         사용자 사용자간의 유사도 기준추천 : 나와 취향이 비슷한 사람이 좋아하는 것을 보여준다
#         비슷한 취향의 사람을 n명 만큼 뽑아서 사용한다 -> top-n방식 
#     아이템기반
#         해당 아이템과 평점 분포가 비슷한 아이템을 추천 해주는것 -> 사용자가 해당 아이템을 좋아하느냐 아니냐가 추천의 기준이 된다
        

# 잠재 요인 협업 필터링

# %% [markdown]
# # 데이터 정재하기

# %%
# 수집한 데이터중 리뷰가 1개인 맥주들이 있다
# 리뷰를 남긴 유저도 마찬가지이다
# 이와같은 경우 추천시스템 저하의 원인이 되므로 최소 10개 이상의 리뷰를 가진 맥주와 유저의 데이터셋을 구성한다.

# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error

import warnings

warnings.filterwarnings('ignore')

data = pd.read_csv('전저리후데이터.csv', encoding='utf-8', index_col=0)
data.head()
# Out:
#                     ID                    맥주이름                 날짜   평점  Aroma  \
# 0   italianjohn(4,613)  Kloud Original Gravity  September 6, 2021  2.8      5
# 1            orda(233)  Kloud Original Gravity    August 29, 2021  3.9     10
# 2  Radek Kliber(7,985)  Kloud Original Gravity       June 5, 2021  2.4      6
# 3    geologyguy(2,380)  Kloud Original Gravity       May 26, 2021  2.3      4
# 4         Wolff90(167)  Kloud Original Gravity  February 16, 2021  1.0      1
#
#    Appearance  Flavor  Mouthfeel  Overall
# 0           3       5          3       12
# 1           5      10          5        9
# 2           3       4          2        9
# 3           3       4          3        9
# 4           1       1          1        6

# %%
# n개 이상의 데이터 리뷰를 남긴 유저, 맥주를 걸러내는 함수
def filtering(data, n):
    select_id = data['ID'].value_counts() >= n
    select_id = select_id[select_id].index.to_list()
    data = data[data['ID'].isin(select_id)]
    
    select_beer = data['맥주이름'].value_counts() >= n
    select_beer = select_beer[select_beer].index.to_list()
    data = data[data['맥주이름'].isin(select_beer)]
    
    return data

data_4 = data.copy()

data_5 = filtering(data_4, 10)

data_5.to_csv('정제된데이터.csv', encoding='utf-8')

# %%
data_5.shape
# Out:
# (39794, 9)

# %% [markdown]
# # 맥주간 유사도 기반 추천

# %%
#코사인 유사도를 사용
data_6 = pd.read_csv('정제된데이터.csv', encoding='utf-8')

# %%
data_6
# Out:
#        Unnamed: 0                     ID                      맥주이름  \
# 0               0     italianjohn(4,613)    Kloud Original Gravity
# 1               2    Radek Kliber(7,985)    Kloud Original Gravity
# 2               3      geologyguy(2,380)    Kloud Original Gravity
# 3               7    snoworsummer(9,000)    Kloud Original Gravity
# 4               9   GuideDogSaint(2,665)    Kloud Original Gravity
# ...           ...                    ...                       ...
# 39789        2461     beerman991979(136)  Warsteiner Premium Verum
# 39790        2463          Aubrey(3,516)  Warsteiner Premium Verum
# 39791        2464            Sammys(427)  Warsteiner Premium Verum
# 39792        2465            Bov(14,984)  Warsteiner Premium Verum
# 39793        2466  PhillyBeer2112(3,252)  Warsteiner Premium Verum
#
#                       날짜   평점  Aroma  Appearance  Flavor  Mouthfeel  Overall
# 0      September 6, 2021  2.8      5           3       5          3       12
# 1           June 5, 2021  2.4      6           3       4          2        9
# 2           May 26, 2021  2.3      4           3       4          3        9
# 3          March 7, 2020  3.0      6           3       6          3       12
# 4       February 8, 2020  2.2      4           2       5          2        9
# ...                  ...  ...    ...         ...     ...        ...      ...
# 39789  September 2, 2000  3.2      6           3       6          3       14
# 39790    August 24, 2000  2.9      5           3       5          3       13
# 39791      July 20, 2000  2.9      7           3       6          3       10
# 39792      June 18, 2000  2.2      5           4       4          2        7
# 39793       May 31, 2000  3.8      7           5       7          4       15
#
# [39794 rows x 10 columns]

# %%
data_6.columns
# Out:
# Index(['Unnamed: 0', 'ID', '맥주이름', '날짜', '평점', 'Aroma', 'Appearance', 'Flavor',
#        'Mouthfeel', 'Overall'],
#       dtype='object')

# %%
data_6 = data_6[['ID', '맥주이름', '날짜', '평점', 'Aroma', 'Appearance', 'Flavor', 'Mouthfeel', 'Overall']]
# data_6.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data_6
# Out:
#                           ID                      맥주이름                 날짜  \
# 0         italianjohn(4,613)    Kloud Original Gravity  September 6, 2021
# 1        Radek Kliber(7,985)    Kloud Original Gravity       June 5, 2021
# 2          geologyguy(2,380)    Kloud Original Gravity       May 26, 2021
# 3        snoworsummer(9,000)    Kloud Original Gravity      March 7, 2020
# 4       GuideDogSaint(2,665)    Kloud Original Gravity   February 8, 2020
# ...                      ...                       ...                ...
# 39789     beerman991979(136)  Warsteiner Premium Verum  September 2, 2000
# 39790          Aubrey(3,516)  Warsteiner Premium Verum    August 24, 2000
# 39791            Sammys(427)  Warsteiner Premium Verum      July 20, 2000
# 39792            Bov(14,984)  Warsteiner Premium Verum      June 18, 2000
# 39793  PhillyBeer2112(3,252)  Warsteiner Premium Verum       May 31, 2000
#
#         평점  Aroma  Appearance  Flavor  Mouthfeel  Overall
# 0      2.8      5           3       5          3       12
# 1      2.4      6           3       4          2        9
# 2      2.3      4           3       4          3        9
# 3      3.0      6           3       6          3       12
# 4      2.2      4           2       5          2        9
# ...    ...    ...         ...     ...        ...      ...
# 39789  3.2      6           3       6          3       14
# 39790  2.9      5           3       5          3       13
# 39791  2.9      7           3       6          3       10
# 39792  2.2      5           4       4          2        7
# 39793  3.8      7           5       7          4       15
#
# [39794 rows x 9 columns]

# %%
ratings = data_6.copy()

# 피벗 테이블을 이용해 유저-아이디 매트릭스 구성
user_item_matrix = ratings.pivot_table('평점', index='ID', columns='맥주이름')

user_item_matrix
# Out:
# 맥주이름                Asahi Super Dry  Asahi Super Dry Black  Bali Hai  \
# ID
# 007lund(92)                     NaN                    NaN       NaN
# 00cobraR(1,103)                 NaN                    NaN       NaN
# 12HundredBaud(262)              2.3                    NaN       NaN
# 16erBlech(560)                  NaN                    NaN       NaN
# 17Beer(1,533)                   3.4                    NaN       NaN
# ...                             ...                    ...       ...
# zebracakes(1,339)               2.7                    NaN       NaN
# ziobarba2000(101)               NaN                    NaN       NaN
# zombywoof(530)                  NaN                    NaN       NaN
# zvikar(11,683)                  1.2                    2.5       NaN
# zvsn(6,347)                     NaN                    NaN       NaN
#
# 맥주이름                Bavaria 8.6 (Original)  Bavaria Pilsener / Premium Beer  \
# ID
# 007lund(92)                            NaN                              NaN
# 00cobraR(1,103)                        NaN                              NaN
# 12HundredBaud(262)                     NaN                              NaN
# 16erBlech(560)                         NaN                              NaN
# 17Beer(1,533)                          NaN                              NaN
# ...                                    ...                              ...
# zebracakes(1,339)                      NaN                              NaN
# ziobarba2000(101)                      NaN                              1.6
# zombywoof(530)                         NaN                              1.5
# zvikar(11,683)                         NaN                              NaN
# zvsn(6,347)                            NaN                              NaN
#
# 맥주이름                Beck's  Berliner Kindl Jubiläums Pilsener Premium  \
# ID
# 007lund(92)            2.6                                        NaN
# 00cobraR(1,103)        2.3                                        NaN
# 12HundredBaud(262)     NaN                                        NaN
# 16erBlech(560)         NaN                                        3.0
# 17Beer(1,533)          NaN                                        NaN
# ...                    ...                                        ...
# zebracakes(1,339)      2.1                                        NaN
# ziobarba2000(101)      1.6                                        NaN
# zombywoof(530)         1.8                                        NaN
# zvikar(11,683)         2.1                                        NaN
# zvsn(6,347)            1.9                                        NaN
#
# 맥주이름                Bintang Pilsener  \
# ID
# 007lund(92)                      NaN
# 00cobraR(1,103)                  NaN
# 12HundredBaud(262)               NaN
# 16erBlech(560)                   NaN
# 17Beer(1,533)                    NaN
# ...                              ...
# zebracakes(1,339)                NaN
# ziobarba2000(101)                NaN
# zombywoof(530)                   NaN
# zvikar(11,683)                   NaN
# zvsn(6,347)                      NaN
#
# 맥주이름                Brooklyn Special Effects (Hoppy Amber/Lager)  Budweiser  \
# ID
# 007lund(92)                                                  NaN        2.0
# 00cobraR(1,103)                                              NaN        1.4
# 12HundredBaud(262)                                           NaN        NaN
# 16erBlech(560)                                               NaN        NaN
# 17Beer(1,533)                                                NaN        NaN
# ...                                                          ...        ...
# zebracakes(1,339)                                            NaN        1.0
# ziobarba2000(101)                                            NaN        2.4
# zombywoof(530)                                               NaN        1.0
# zvikar(11,683)                                               NaN        1.4
# zvsn(6,347)                                                  NaN        NaN
#
# 맥주이름                ...  Stephans Bräu Premium Lager  \
# ID                  ...
# 007lund(92)         ...                          NaN
# 00cobraR(1,103)     ...                          NaN
# 12HundredBaud(262)  ...                          NaN
# 16erBlech(560)      ...                          NaN
# 17Beer(1,533)       ...                          NaN
# ...                 ...                          ...
# zebracakes(1,339)   ...                          NaN
# ziobarba2000(101)   ...                          NaN
# zombywoof(530)      ...                          NaN
# zvikar(11,683)      ...                          2.2
# zvsn(6,347)         ...                          NaN
#
# 맥주이름                Stephans Bräu Premium Pilsener  \
# ID
# 007lund(92)                                    NaN
# 00cobraR(1,103)                                NaN
# 12HundredBaud(262)                             NaN
# 16erBlech(560)                                 NaN
# 17Beer(1,533)                                  NaN
# ...                                            ...
# zebracakes(1,339)                              NaN
# ziobarba2000(101)                              NaN
# zombywoof(530)                                 NaN
# zvikar(11,683)                                 NaN
# zvsn(6,347)                                    NaN
#
# 맥주이름                Suntory The Premium Malt's  Tiger Beer  \
# ID
# 007lund(92)                                NaN         NaN
# 00cobraR(1,103)                            NaN         NaN
# 12HundredBaud(262)                         NaN         NaN
# 16erBlech(560)                             NaN         NaN
# 17Beer(1,533)                              NaN         2.6
# ...                                        ...         ...
# zebracakes(1,339)                          2.7         NaN
# ziobarba2000(101)                          NaN         NaN
# zombywoof(530)                             NaN         NaN
# zvikar(11,683)                             NaN         1.7
# zvsn(6,347)                                NaN         NaN
#
# 맥주이름                Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# ID
# 007lund(92)                        NaN       2.5                  NaN
# 00cobraR(1,103)                    NaN       2.1                  NaN
# 12HundredBaud(262)                 NaN       NaN                  NaN
# 16erBlech(560)                     NaN       3.0                  NaN
# 17Beer(1,533)                      NaN       2.8                  NaN
# ...                                ...       ...                  ...
# zebracakes(1,339)                  NaN       1.7                  NaN
# ziobarba2000(101)                  NaN       NaN                  NaN
# zombywoof(530)                     NaN       NaN                  NaN
# zvikar(11,683)                     NaN       1.7                  NaN
# zvsn(6,347)                        NaN       NaN                  NaN
#
# 맥주이름                Victoria Bitter  Volfas Engelman Grünberger Hefeweizen  \
# ID
# 007lund(92)                     NaN                                    NaN
# 00cobraR(1,103)                 NaN                                    NaN
# 12HundredBaud(262)              NaN                                    NaN
# 16erBlech(560)                  2.0                                    NaN
# 17Beer(1,533)                   NaN                                    NaN
# ...                             ...                                    ...
# zebracakes(1,339)               NaN                                    NaN
# ziobarba2000(101)               NaN                                    NaN
# zombywoof(530)                  NaN                                    NaN
# zvikar(11,683)                  1.4                                    NaN
# zvsn(6,347)                     NaN                                    NaN
#
# 맥주이름                Warsteiner Premium Verum
# ID
# 007lund(92)                              4.1
# 00cobraR(1,103)                          NaN
# 12HundredBaud(262)                       NaN
# 16erBlech(560)                           2.5
# 17Beer(1,533)                            3.5
# ...                                      ...
# zebracakes(1,339)                        2.3
# ziobarba2000(101)                        2.4
# zombywoof(530)                           2.5
# zvikar(11,683)                           2.3
# zvsn(6,347)                              2.5
#
# [2238 rows x 66 columns]

# %%
# user_item_matrix -> Collaborating Filtering(협업필터링) -> item_user_matrix로 변환
user_item_matrix_T = user_item_matrix.T
user_item_matrix_T
# Out:
# ID                                     007lund(92)  00cobraR(1,103)  \
# 맥주이름
# Asahi Super Dry                                NaN              NaN
# Asahi Super Dry Black                          NaN              NaN
# Bali Hai                                       NaN              NaN
# Bavaria 8.6 (Original)                         NaN              NaN
# Bavaria Pilsener / Premium Beer                NaN              NaN
# ...                                            ...              ...
# Tsingtao                                       2.5              2.1
# Tsingtao Wheat Beer                            NaN              NaN
# Victoria Bitter                                NaN              NaN
# Volfas Engelman Grünberger Hefeweizen          NaN              NaN
# Warsteiner Premium Verum                       4.1              NaN
#
# ID                                     12HundredBaud(262)  16erBlech(560)  \
# 맥주이름
# Asahi Super Dry                                       2.3             NaN
# Asahi Super Dry Black                                 NaN             NaN
# Bali Hai                                              NaN             NaN
# Bavaria 8.6 (Original)                                NaN             NaN
# Bavaria Pilsener / Premium Beer                       NaN             NaN
# ...                                                   ...             ...
# Tsingtao                                              NaN             3.0
# Tsingtao Wheat Beer                                   NaN             NaN
# Victoria Bitter                                       NaN             2.0
# Volfas Engelman Grünberger Hefeweizen                 NaN             NaN
# Warsteiner Premium Verum                              NaN             2.5
#
# ID                                     17Beer(1,533)  17thfloor(2,444)  \
# 맥주이름
# Asahi Super Dry                                  3.4               2.0
# Asahi Super Dry Black                            NaN               NaN
# Bali Hai                                         NaN               NaN
# Bavaria 8.6 (Original)                           NaN               NaN
# Bavaria Pilsener / Premium Beer                  NaN               NaN
# ...                                              ...               ...
# Tsingtao                                         2.8               2.5
# Tsingtao Wheat Beer                              NaN               NaN
# Victoria Bitter                                  NaN               NaN
# Volfas Engelman Grünberger Hefeweizen            NaN               NaN
# Warsteiner Premium Verum                         3.5               2.5
#
# ID                                     17wojownik(1,415)  184601(206)  \
# 맥주이름
# Asahi Super Dry                                      NaN          2.4
# Asahi Super Dry Black                                NaN          NaN
# Bali Hai                                             NaN          NaN
# Bavaria 8.6 (Original)                               NaN          NaN
# Bavaria Pilsener / Premium Beer                      NaN          1.7
# ...                                                  ...          ...
# Tsingtao                                             2.1          0.9
# Tsingtao Wheat Beer                                  NaN          NaN
# Victoria Bitter                                      NaN          NaN
# Volfas Engelman Grünberger Hefeweizen                NaN          NaN
# Warsteiner Premium Verum                             3.5          3.3
#
# ID                                     1FastSTi(3,361)  20107589(748)  ...  \
# 맥주이름                                                                   ...
# Asahi Super Dry                                    NaN            NaN  ...
# Asahi Super Dry Black                              NaN            NaN  ...
# Bali Hai                                           NaN            NaN  ...
# Bavaria 8.6 (Original)                             NaN            NaN  ...
# Bavaria Pilsener / Premium Beer                    NaN            NaN  ...
# ...                                                ...            ...  ...
# Tsingtao                                           NaN            NaN  ...
# Tsingtao Wheat Beer                                NaN            NaN  ...
# Victoria Bitter                                    NaN            NaN  ...
# Volfas Engelman Grünberger Hefeweizen              NaN            NaN  ...
# Warsteiner Premium Verum                           NaN            2.5  ...
#
# ID                                     zappafan99(463)  zathrus13(1,776)  \
# 맥주이름
# Asahi Super Dry                                    NaN               NaN
# Asahi Super Dry Black                              NaN               NaN
# Bali Hai                                           NaN               NaN
# Bavaria 8.6 (Original)                             NaN               NaN
# Bavaria Pilsener / Premium Beer                    NaN               NaN
# ...                                                ...               ...
# Tsingtao                                           NaN               2.2
# Tsingtao Wheat Beer                                NaN               NaN
# Victoria Bitter                                    NaN               NaN
# Volfas Engelman Grünberger Hefeweizen              NaN               NaN
# Warsteiner Premium Verum                           3.3               NaN
#
# ID                                     zborgerd(187)  zdet444dd(440)  \
# 맥주이름
# Asahi Super Dry                                  1.8             1.8
# Asahi Super Dry Black                            NaN             NaN
# Bali Hai                                         NaN             NaN
# Bavaria 8.6 (Original)                           NaN             NaN
# Bavaria Pilsener / Premium Beer                  NaN             NaN
# ...                                              ...             ...
# Tsingtao                                         2.3             2.0
# Tsingtao Wheat Beer                              NaN             NaN
# Victoria Bitter                                  NaN             NaN
# Volfas Engelman Grünberger Hefeweizen            NaN             NaN
# Warsteiner Premium Verum                         2.9             NaN
#
# ID                                     zdk(1,917)  zebracakes(1,339)  \
# 맥주이름
# Asahi Super Dry                               1.8                2.7
# Asahi Super Dry Black                         NaN                NaN
# Bali Hai                                      NaN                NaN
# Bavaria 8.6 (Original)                        NaN                NaN
# Bavaria Pilsener / Premium Beer               3.0                NaN
# ...                                           ...                ...
# Tsingtao                                      1.8                1.7
# Tsingtao Wheat Beer                           NaN                NaN
# Victoria Bitter                               NaN                NaN
# Volfas Engelman Grünberger Hefeweizen         NaN                NaN
# Warsteiner Premium Verum                      NaN                2.3
#
# ID                                     ziobarba2000(101)  zombywoof(530)  \
# 맥주이름
# Asahi Super Dry                                      NaN             NaN
# Asahi Super Dry Black                                NaN             NaN
# Bali Hai                                             NaN             NaN
# Bavaria 8.6 (Original)                               NaN             NaN
# Bavaria Pilsener / Premium Beer                      1.6             1.5
# ...                                                  ...             ...
# Tsingtao                                             NaN             NaN
# Tsingtao Wheat Beer                                  NaN             NaN
# Victoria Bitter                                      NaN             NaN
# Volfas Engelman Grünberger Hefeweizen                NaN             NaN
# Warsteiner Premium Verum                             2.4             2.5
#
# ID                                     zvikar(11,683)  zvsn(6,347)
# 맥주이름
# Asahi Super Dry                                   1.2          NaN
# Asahi Super Dry Black                             2.5          NaN
# Bali Hai                                          NaN          NaN
# Bavaria 8.6 (Original)                            NaN          NaN
# Bavaria Pilsener / Premium Beer                   NaN          NaN
# ...                                               ...          ...
# Tsingtao                                          1.7          NaN
# Tsingtao Wheat Beer                               NaN          NaN
# Victoria Bitter                                   1.4          NaN
# Volfas Engelman Grünberger Hefeweizen             NaN          NaN
# Warsteiner Premium Verum                          2.3          2.5
#
# [66 rows x 2238 columns]

# %%
# nan -> 0
user_item_matrix_T = user_item_matrix_T.fillna(0)

# %%
user_item_matrix_T
# Out:
# ID                                     007lund(92)  00cobraR(1,103)  \
# 맥주이름
# Asahi Super Dry                                0.0              0.0
# Asahi Super Dry Black                          0.0              0.0
# Bali Hai                                       0.0              0.0
# Bavaria 8.6 (Original)                         0.0              0.0
# Bavaria Pilsener / Premium Beer                0.0              0.0
# ...                                            ...              ...
# Tsingtao                                       2.5              2.1
# Tsingtao Wheat Beer                            0.0              0.0
# Victoria Bitter                                0.0              0.0
# Volfas Engelman Grünberger Hefeweizen          0.0              0.0
# Warsteiner Premium Verum                       4.1              0.0
#
# ID                                     12HundredBaud(262)  16erBlech(560)  \
# 맥주이름
# Asahi Super Dry                                       2.3             0.0
# Asahi Super Dry Black                                 0.0             0.0
# Bali Hai                                              0.0             0.0
# Bavaria 8.6 (Original)                                0.0             0.0
# Bavaria Pilsener / Premium Beer                       0.0             0.0
# ...                                                   ...             ...
# Tsingtao                                              0.0             3.0
# Tsingtao Wheat Beer                                   0.0             0.0
# Victoria Bitter                                       0.0             2.0
# Volfas Engelman Grünberger Hefeweizen                 0.0             0.0
# Warsteiner Premium Verum                              0.0             2.5
#
# ID                                     17Beer(1,533)  17thfloor(2,444)  \
# 맥주이름
# Asahi Super Dry                                  3.4               2.0
# Asahi Super Dry Black                            0.0               0.0
# Bali Hai                                         0.0               0.0
# Bavaria 8.6 (Original)                           0.0               0.0
# Bavaria Pilsener / Premium Beer                  0.0               0.0
# ...                                              ...               ...
# Tsingtao                                         2.8               2.5
# Tsingtao Wheat Beer                              0.0               0.0
# Victoria Bitter                                  0.0               0.0
# Volfas Engelman Grünberger Hefeweizen            0.0               0.0
# Warsteiner Premium Verum                         3.5               2.5
#
# ID                                     17wojownik(1,415)  184601(206)  \
# 맥주이름
# Asahi Super Dry                                      0.0          2.4
# Asahi Super Dry Black                                0.0          0.0
# Bali Hai                                             0.0          0.0
# Bavaria 8.6 (Original)                               0.0          0.0
# Bavaria Pilsener / Premium Beer                      0.0          1.7
# ...                                                  ...          ...
# Tsingtao                                             2.1          0.9
# Tsingtao Wheat Beer                                  0.0          0.0
# Victoria Bitter                                      0.0          0.0
# Volfas Engelman Grünberger Hefeweizen                0.0          0.0
# Warsteiner Premium Verum                             3.5          3.3
#
# ID                                     1FastSTi(3,361)  20107589(748)  ...  \
# 맥주이름                                                                   ...
# Asahi Super Dry                                    0.0            0.0  ...
# Asahi Super Dry Black                              0.0            0.0  ...
# Bali Hai                                           0.0            0.0  ...
# Bavaria 8.6 (Original)                             0.0            0.0  ...
# Bavaria Pilsener / Premium Beer                    0.0            0.0  ...
# ...                                                ...            ...  ...
# Tsingtao                                           0.0            0.0  ...
# Tsingtao Wheat Beer                                0.0            0.0  ...
# Victoria Bitter                                    0.0            0.0  ...
# Volfas Engelman Grünberger Hefeweizen              0.0            0.0  ...
# Warsteiner Premium Verum                           0.0            2.5  ...
#
# ID                                     zappafan99(463)  zathrus13(1,776)  \
# 맥주이름
# Asahi Super Dry                                    0.0               0.0
# Asahi Super Dry Black                              0.0               0.0
# Bali Hai                                           0.0               0.0
# Bavaria 8.6 (Original)                             0.0               0.0
# Bavaria Pilsener / Premium Beer                    0.0               0.0
# ...                                                ...               ...
# Tsingtao                                           0.0               2.2
# Tsingtao Wheat Beer                                0.0               0.0
# Victoria Bitter                                    0.0               0.0
# Volfas Engelman Grünberger Hefeweizen              0.0               0.0
# Warsteiner Premium Verum                           3.3               0.0
#
# ID                                     zborgerd(187)  zdet444dd(440)  \
# 맥주이름
# Asahi Super Dry                                  1.8             1.8
# Asahi Super Dry Black                            0.0             0.0
# Bali Hai                                         0.0             0.0
# Bavaria 8.6 (Original)                           0.0             0.0
# Bavaria Pilsener / Premium Beer                  0.0             0.0
# ...                                              ...             ...
# Tsingtao                                         2.3             2.0
# Tsingtao Wheat Beer                              0.0             0.0
# Victoria Bitter                                  0.0             0.0
# Volfas Engelman Grünberger Hefeweizen            0.0             0.0
# Warsteiner Premium Verum                         2.9             0.0
#
# ID                                     zdk(1,917)  zebracakes(1,339)  \
# 맥주이름
# Asahi Super Dry                               1.8                2.7
# Asahi Super Dry Black                         0.0                0.0
# Bali Hai                                      0.0                0.0
# Bavaria 8.6 (Original)                        0.0                0.0
# Bavaria Pilsener / Premium Beer               3.0                0.0
# ...                                           ...                ...
# Tsingtao                                      1.8                1.7
# Tsingtao Wheat Beer                           0.0                0.0
# Victoria Bitter                               0.0                0.0
# Volfas Engelman Grünberger Hefeweizen         0.0                0.0
# Warsteiner Premium Verum                      0.0                2.3
#
# ID                                     ziobarba2000(101)  zombywoof(530)  \
# 맥주이름
# Asahi Super Dry                                      0.0             0.0
# Asahi Super Dry Black                                0.0             0.0
# Bali Hai                                             0.0             0.0
# Bavaria 8.6 (Original)                               0.0             0.0
# Bavaria Pilsener / Premium Beer                      1.6             1.5
# ...                                                  ...             ...
# Tsingtao                                             0.0             0.0
# Tsingtao Wheat Beer                                  0.0             0.0
# Victoria Bitter                                      0.0             0.0
# Volfas Engelman Grünberger Hefeweizen                0.0             0.0
# Warsteiner Premium Verum                             2.4             2.5
#
# ID                                     zvikar(11,683)  zvsn(6,347)
# 맥주이름
# Asahi Super Dry                                   1.2          0.0
# Asahi Super Dry Black                             2.5          0.0
# Bali Hai                                          0.0          0.0
# Bavaria 8.6 (Original)                            0.0          0.0
# Bavaria Pilsener / Premium Beer                   0.0          0.0
# ...                                               ...          ...
# Tsingtao                                          1.7          0.0
# Tsingtao Wheat Beer                               0.0          0.0
# Victoria Bitter                                   1.4          0.0
# Volfas Engelman Grünberger Hefeweizen             0.0          0.0
# Warsteiner Premium Verum                          2.3          2.5
#
# [66 rows x 2238 columns]

# %%
# 아이템 - 유저 매트릭스로부터 코사인 유사도 구하기
item_user_cos_sim = cosine_similarity(user_item_matrix_T, user_item_matrix_T)

# cosine_similarity()로 반환된 넘파이 행렬에 맥주이름을 넣어서 (인덱스와 컬럼에) DataFrame로 변환
item_user_cos_sim_df = pd.DataFrame(data=item_user_cos_sim, index=user_item_matrix.columns, columns=user_item_matrix.columns)

# item_user_cos_sim_df 데이터프레임 확임
print(item_user_cos_sim_df.shape)

item_user_cos_sim_df
# Out:
# (66, 66)
# 맥주이름                                   Asahi Super Dry  Asahi Super Dry Black  \
# 맥주이름
# Asahi Super Dry                               1.000000               0.223041
# Asahi Super Dry Black                         0.223041               1.000000
# Bali Hai                                      0.238765               0.106856
# Bavaria 8.6 (Original)                        0.344020               0.111999
# Bavaria Pilsener / Premium Beer               0.511228               0.154095
# ...                                                ...                    ...
# Tsingtao                                      0.671117               0.155719
# Tsingtao Wheat Beer                           0.113389               0.074714
# Victoria Bitter                               0.432535               0.208779
# Volfas Engelman Grünberger Hefeweizen         0.043247               0.024217
# Warsteiner Premium Verum                      0.628835               0.165328
#
# 맥주이름                                   Bali Hai  Bavaria 8.6 (Original)  \
# 맥주이름
# Asahi Super Dry                        0.238765                0.344020
# Asahi Super Dry Black                  0.106856                0.111999
# Bali Hai                               1.000000                0.175832
# Bavaria 8.6 (Original)                 0.175832                1.000000
# Bavaria Pilsener / Premium Beer        0.230795                0.392127
# ...                                         ...                     ...
# Tsingtao                               0.245997                0.318188
# Tsingtao Wheat Beer                    0.023391                0.094790
# Victoria Bitter                        0.279863                0.288396
# Volfas Engelman Grünberger Hefeweizen  0.019706                0.027296
# Warsteiner Premium Verum               0.222181                0.336111
#
# 맥주이름                                   Bavaria Pilsener / Premium Beer  \
# 맥주이름
# Asahi Super Dry                                               0.511228
# Asahi Super Dry Black                                         0.154095
# Bali Hai                                                      0.230795
# Bavaria 8.6 (Original)                                        0.392127
# Bavaria Pilsener / Premium Beer                               1.000000
# ...                                                                ...
# Tsingtao                                                      0.519041
# Tsingtao Wheat Beer                                           0.102306
# Victoria Bitter                                               0.397206
# Volfas Engelman Grünberger Hefeweizen                         0.091300
# Warsteiner Premium Verum                                      0.530187
#
# 맥주이름                                     Beck's  \
# 맥주이름
# Asahi Super Dry                        0.639790
# Asahi Super Dry Black                  0.171389
# Bali Hai                               0.234089
# Bavaria 8.6 (Original)                 0.327839
# Bavaria Pilsener / Premium Beer        0.524610
# ...                                         ...
# Tsingtao                               0.663783
# Tsingtao Wheat Beer                    0.095282
# Victoria Bitter                        0.411391
# Volfas Engelman Grünberger Hefeweizen  0.088643
# Warsteiner Premium Verum               0.722309
#
# 맥주이름                                   Berliner Kindl Jubiläums Pilsener Premium  \
# 맥주이름
# Asahi Super Dry                                                         0.299976
# Asahi Super Dry Black                                                   0.117009
# Bali Hai                                                                0.162438
# Bavaria 8.6 (Original)                                                  0.235075
# Bavaria Pilsener / Premium Beer                                         0.291404
# ...                                                                          ...
# Tsingtao                                                                0.282319
# Tsingtao Wheat Beer                                                     0.151404
# Victoria Bitter                                                         0.313526
# Volfas Engelman Grünberger Hefeweizen                                   0.143547
# Warsteiner Premium Verum                                                0.304010
#
# 맥주이름                                   Bintang Pilsener  \
# 맥주이름
# Asahi Super Dry                                0.416955
# Asahi Super Dry Black                          0.192051
# Bali Hai                                       0.375601
# Bavaria 8.6 (Original)                         0.298135
# Bavaria Pilsener / Premium Beer                0.377806
# ...                                                 ...
# Tsingtao                                       0.417059
# Tsingtao Wheat Beer                            0.078151
# Victoria Bitter                                0.461927
# Volfas Engelman Grünberger Hefeweizen          0.020469
# Warsteiner Premium Verum                       0.388258
#
# 맥주이름                                   Brooklyn Special Effects (Hoppy Amber/Lager)  \
# 맥주이름
# Asahi Super Dry                                                            0.206415
# Asahi Super Dry Black                                                      0.086038
# Bali Hai                                                                   0.146153
# Bavaria 8.6 (Original)                                                     0.171508
# Bavaria Pilsener / Premium Beer                                            0.224073
# ...                                                                             ...
# Tsingtao                                                                   0.191618
# Tsingtao Wheat Beer                                                        0.119699
# Victoria Bitter                                                            0.211944
# Volfas Engelman Grünberger Hefeweizen                                      0.046449
# Warsteiner Premium Verum                                                   0.203623
#
# 맥주이름                                   Budweiser  ...  \
# 맥주이름                                              ...
# Asahi Super Dry                         0.635402  ...
# Asahi Super Dry Black                   0.162172  ...
# Bali Hai                                0.199003  ...
# Bavaria 8.6 (Original)                  0.316328  ...
# Bavaria Pilsener / Premium Beer         0.493460  ...
# ...                                          ...  ...
# Tsingtao                                0.636686  ...
# Tsingtao Wheat Beer                     0.095422  ...
# Victoria Bitter                         0.396646  ...
# Volfas Engelman Grünberger Hefeweizen   0.060738  ...
# Warsteiner Premium Verum                0.667754  ...
#
# 맥주이름                                   Stephans Bräu Premium Lager  \
# 맥주이름
# Asahi Super Dry                                           0.125003
# Asahi Super Dry Black                                     0.078768
# Bali Hai                                                  0.000000
# Bavaria 8.6 (Original)                                    0.146835
# Bavaria Pilsener / Premium Beer                           0.133090
# ...                                                            ...
# Tsingtao                                                  0.128745
# Tsingtao Wheat Beer                                       0.079757
# Victoria Bitter                                           0.050001
# Volfas Engelman Grünberger Hefeweizen                     0.196251
# Warsteiner Premium Verum                                  0.117962
#
# 맥주이름                                   Stephans Bräu Premium Pilsener  \
# 맥주이름
# Asahi Super Dry                                              0.145858
# Asahi Super Dry Black                                        0.055430
# Bali Hai                                                     0.034942
# Bavaria 8.6 (Original)                                       0.172443
# Bavaria Pilsener / Premium Beer                              0.162515
# ...                                                               ...
# Tsingtao                                                     0.119454
# Tsingtao Wheat Beer                                          0.000000
# Victoria Bitter                                              0.077825
# Volfas Engelman Grünberger Hefeweizen                        0.135270
# Warsteiner Premium Verum                                     0.124844
#
# 맥주이름                                   Suntory The Premium Malt's  Tiger Beer  \
# 맥주이름
# Asahi Super Dry                                          0.271102    0.632666
# Asahi Super Dry Black                                    0.377076    0.188509
# Bali Hai                                                 0.131443    0.260436
# Bavaria 8.6 (Original)                                   0.108871    0.330234
# Bavaria Pilsener / Premium Beer                          0.204315    0.520516
# ...                                                           ...         ...
# Tsingtao                                                 0.237704    0.644651
# Tsingtao Wheat Beer                                      0.079778    0.089784
# Victoria Bitter                                          0.271745    0.488273
# Volfas Engelman Grünberger Hefeweizen                    0.019014    0.061625
# Warsteiner Premium Verum                                 0.223380    0.613337
#
# 맥주이름                                   Tiger Radler Lemon  Tsingtao  \
# 맥주이름
# Asahi Super Dry                                  0.098839  0.671117
# Asahi Super Dry Black                            0.141308  0.155719
# Bali Hai                                         0.074863  0.245997
# Bavaria 8.6 (Original)                           0.095067  0.318188
# Bavaria Pilsener / Premium Beer                  0.063026  0.519041
# ...                                                   ...       ...
# Tsingtao                                         0.083176  1.000000
# Tsingtao Wheat Beer                              0.045298  0.079949
# Victoria Bitter                                  0.103507  0.417881
# Volfas Engelman Grünberger Hefeweizen            0.000000  0.077563
# Warsteiner Premium Verum                         0.064367  0.665518
#
# 맥주이름                                   Tsingtao Wheat Beer  Victoria Bitter  \
# 맥주이름
# Asahi Super Dry                                   0.113389         0.432535
# Asahi Super Dry Black                             0.074714         0.208779
# Bali Hai                                          0.023391         0.279863
# Bavaria 8.6 (Original)                            0.094790         0.288396
# Bavaria Pilsener / Premium Beer                   0.102306         0.397206
# ...                                                    ...              ...
# Tsingtao                                          0.079949         0.417881
# Tsingtao Wheat Beer                               1.000000         0.067840
# Victoria Bitter                                   0.067840         1.000000
# Volfas Engelman Grünberger Hefeweizen             0.156450         0.039559
# Warsteiner Premium Verum                          0.067908         0.389772
#
# 맥주이름                                   Volfas Engelman Grünberger Hefeweizen  \
# 맥주이름
# Asahi Super Dry                                                     0.043247
# Asahi Super Dry Black                                               0.024217
# Bali Hai                                                            0.019706
# Bavaria 8.6 (Original)                                              0.027296
# Bavaria Pilsener / Premium Beer                                     0.091300
# ...                                                                      ...
# Tsingtao                                                            0.077563
# Tsingtao Wheat Beer                                                 0.156450
# Victoria Bitter                                                     0.039559
# Volfas Engelman Grünberger Hefeweizen                               1.000000
# Warsteiner Premium Verum                                            0.067911
#
# 맥주이름                                   Warsteiner Premium Verum
# 맥주이름
# Asahi Super Dry                                        0.628835
# Asahi Super Dry Black                                  0.165328
# Bali Hai                                               0.222181
# Bavaria 8.6 (Original)                                 0.336111
# Bavaria Pilsener / Premium Beer                        0.530187
# ...                                                         ...
# Tsingtao                                               0.665518
# Tsingtao Wheat Beer                                    0.067908
# Victoria Bitter                                        0.389772
# Volfas Engelman Grünberger Hefeweizen                  0.067911
# Warsteiner Premium Verum                               1.000000
#
# [66 rows x 66 columns]

# %%
# 맥주 : 66개
user_item_matrix.columns
# Out:
# Index(['Asahi Super Dry', 'Asahi Super Dry Black', 'Bali Hai',
#        'Bavaria 8.6 (Original)', 'Bavaria Pilsener / Premium Beer', 'Beck's',
#        'Berliner Kindl Jubiläums Pilsener Premium', 'Bintang Pilsener',
#        'Brooklyn Special Effects (Hoppy Amber/Lager)', 'Budweiser',
#        'Carlsberg Pilsner', 'Cass Fresh', 'Castlemaine XXXX Gold Lager',
#        'Desperados', 'Edelweiss Weissbier Snowfresh',
#        'Egger Grapefruit Radler', 'Egger Märzenbier', 'Egger Zwickl',
#        'Eichbaum Apostel Bräu', 'Erdinger Weissbier',
#        'Erdinger Weissbier Dunkel',
#        'Franziskaner Hefe-Weissbier / Weissbier Naturtrub',
#        'Gambrinus Originál 10° (Desítka)', 'Grolsch Premium Lager',
#        'Guinness Draught', 'Guinness Original 4.2% (Ireland/UK)',
#        'Harbin Beer', 'Heineken', 'Heineken Dark Lager', 'Hite D (Dry Finish)',
#        'Hite Extra Cold', 'Hite Prime Max', 'Hoegaarden Rosée',
#        'Holsten Premium Bier', 'Jeju Wit Ale', 'Kirin Ichiban',
#        'Kloud Fitz Super Clear', 'Kloud Original Gravity',
#        'Kozel Černý (Dark) 10°', 'Krombacher Weizen', 'Kronenbourg 1664 Blanc',
#        'Lapin Kulta IV A', 'Leffe Brune / Bruin / Brown',
#        'Löwenbräu Original (4.2%)', 'Miller Genuine Draft (MGD)',
#        'OB Premier Pilsner', 'Paulaner Hefe-Weissbier',
#        'Peroni Nastro Azzurro', 'Pilsner Urquell', 'Red Rock', 'San Miguel',
#        'Sapporo Premium Beer / Draft Beer', 'Sapporo Yebisu',
#        'Schöfferhofer Grapefruit', 'Stella Artois',
#        'Stephans Bräu Hefe-Weizen Naturtrüb', 'Stephans Bräu Premium Lager',
#        'Stephans Bräu Premium Pilsener', 'Suntory The Premium Malt's',
#        'Tiger Beer', 'Tiger Radler Lemon', 'Tsingtao', 'Tsingtao Wheat Beer',
#        'Victoria Bitter', 'Volfas Engelman Grünberger Hefeweizen',
#        'Warsteiner Premium Verum'],
#       dtype='object', name='맥주이름')

# %%
# 코젤 맥주와 유사도가 높은 맥주 5개만 추출하기
item_user_cos_sim_df['Kozel Černý (Dark) 10°'].sort_values(ascending=False)[:5]
# Out:
# 맥주이름
# Kozel Černý (Dark) 10°         1.000000
# Leffe Brune / Bruin / Brown    0.546228
# Pilsner Urquell                0.537959
# Paulaner Hefe-Weissbier        0.517370
# Erdinger Weissbier             0.516352
# Name: Kozel Černý (Dark) 10°, dtype: float64

# %%
# 호가든 맥주와 유사도가 높은 맥주 5개만 추출하기
item_user_cos_sim_df['Hoegaarden Rosée'].sort_values(ascending=False)[:5]
# Out:
# 맥주이름
# Hoegaarden Rosée               1.000000
# Leffe Brune / Bruin / Brown    0.470784
# Krombacher Weizen              0.442121
# Kronenbourg 1664 Blanc         0.441555
# Erdinger Weissbier Dunkel      0.434630
# Name: Hoegaarden Rosée, dtype: float64
