# %%
# pip install selenium

# %%
# pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 파일 이름, 디렉터리 이름 또는 볼륨 레이블 구문이 잘못되었습니다.

# %%
# pip install xlsxwriter
#     result.to_excel("beer_n_"+str(k)+".xlsx", engine='xlsxwriter')
# engine='xlsxwriter' 추가

# %%
import pandas as pd
import numpy as np
import time

import re

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
# 수집할 맥주 목록
beer_list = ['Hoegaarden']

# %%
len(beer_list)
# Out:
# 1

# %%
# beer_n_47.xlsx(beer_n_47.csv)'Bali Hai Premium Larger' = 'Bali Hai' 로 수정
# Out:
#   File "C:\Users\adele\AppData\Local\Temp/ipykernel_40256/3399876474.py", line 1
#     beer_n_47.xlsx(beer_n_47.csv)'Bali Hai Premium Larger' = 'Bali Hai' 로 수정
#                                  ^
# SyntaxError: invalid syntax

# %%
//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/div[1]/img

# %%
# 데이터프레임으로 저장
beer_list = pd.DataFrame(data=beer_list, columns=['검색이름'])

# %%
beer_list
# Out:
#          검색이름
# 0  Hoegaarden

# %%
#r'C:\Users\adele\sel\chromedriver.exe'
# 'C:\\Users\\adele\\sel\\chromedriver.exe'
# 'C:/Users/adele/sel/chromedriver.exe'

# C:/Users/adele/sel/chromedriver.exe
# Out:
#   File "C:\Users\adele\AppData\Local\Temp/ipykernel_27604/2551186078.py", line 5
#     C:/Users/adele/sel/chromedriver.exe
#       ^
# SyntaxError: invalid syntax

# %%
# 데이터 프레임 생성
data = pd.DataFrame(data=[], columns=['맥주정보', '검색이름', '맥주이름'])

# chromedriver.exe 파일 경로 설정
chromedriver = 'C:/Users/adele/sel/chromedriver.exe'
# 크롤링 할 경로 설정
url = 'https://www.ratebeer.com/search?tab=beer'

# 셀레니움으로 웹브라우저를 오픈합니다.
driver = webdriver.Chrome(chromedriver)
driver.get(url)
driver.set_window_size(900, 900)
time.sleep(1)

# %%
def crawl(driver, beer, data, k):
    # 데이터 프레임 생성
    data = pd.DataFrame(data=[], columns=['맥주정보', '검색이름', '맥주이름'])

    # url open
    print('url_open... {0} 맥주 데이터를 수집합니다..'.format(beer))
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    driver.set_window_size(900, 900)

    # 1번 사진에 해당 : 맥주 검색
    time.sleep(2)
    element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div/input')
    time.sleep(2)
    element.click()
    time.sleep(2)
    element.send_keys(beer)
    time.sleep(3)
    
    # 2번 사진에 해당 : 상품 선택
    driver.find_element_by_xpath('//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div[2]/a[2]/div').click()
    #     //*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div[2]/a[2]/div 호가든

    # 3번 사진에 해당 : 상품 이름 수집
    time.sleep(3)
    beer_name = driver.find_element_by_css_selector('.MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.mt-3.MuiTypography-h4').text

    error_cnt = 0

    while 1:
        try :
            # 4번 사진에 해당 : 전체 리뷰 개수 수집
            time.sleep(3)
            string = driver.find_element_by_class_name('MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.MuiTypography-h6').text

            # ,가 포함되어 있는지에 대한 로직
            extract = re.compile('[0-9]*,*[0-9]+')
            str_num = extract.findall(string)
            str_num = str_num[0]

            print('성공... while문을 탈출합니다.')
            break
        except :
            print('오류 발생.. 다시 시작합니다.')

            error_cnt += 1

            if error_cnt == 5:
                print('연속된 오류로 다음 맥주로 넘어갑니다...')
                return

    if ',' in str_num:
        str_num = str_num.split(',')
        str_num = int(str_num[0]+str_num[1])
        num = str_num
    else:
        num = int(str_num)

    # 5번 사진에 해당 : Score breakdown 클릭
    time.sleep(3)
    element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
    time.sleep(3)
    # 해당 element로 이동하는 코드입니다. 반드시 적어주세요.
    driver.execute_script("arguments[0].click();", element)

    # 수집할 Page 수를 계산합니다.
    page_num = num // 15 + 1


    for i in range(page_num):
        print(i+1, '번째 페이지입니다.')

        # 6번 사진에 해당 : 전체 맥주 정보를 통째로 수집
        time.sleep(3)
        beer_info = driver.find_elements_by_css_selector('.px-4.fj-s.f-wrap')

        tmp = []

        # 수집한 것을 데이터프레임에 저장
        for i in range(len(beer_info)):
            tmp.append(beer_info[i].text)

        tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
        tmp['맥주이름'] = beer_name
        tmp['검색이름'] = beer
        data = pd.concat([data, tmp])

        # 다음 페이지로 넘어가기 : 7번 사진에 해당합니다.
        # div, span, title 태그 후 속성은 class 외에도 사용 가능
        try :
            element = driver.find_element_by_xpath('//button[@title="Next page"]/span[@class="MuiIconButton-label"]')
            time.sleep(3)
            driver.execute_script("arguments[0].click();", element)
        except:
            print('마지막 페이지입니다.')

    # 데이터가 중복 수집될 경우 리뷰 수 만큼만 Cut
    if num != len(data):
        data = data[:num]

    print('리뷰수 : ', num, '수집된 리뷰수 : ', len(data))

    # 데이터를 csv, excel 파일로 저장합니다.
    result = pd.merge(data, beer_list, on='검색이름', how='left')
    result.to_csv("beer_n_"+str(k)+".csv", encoding='utf-8')
    result.to_excel("beer_n_"+str(k)+".xlsx", engine='xlsxwriter')

    driver.quit()

    return result

# %%
for k in range(len(beer_list)):
    result = crawl(driver, beer_list['검색이름'].iloc[k], data, k)
# Out:
# url_open... Hoegaarden 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# 152 번째 페이지입니다.
# 153 번째 페이지입니다.
# 154 번째 페이지입니다.
# 155 번째 페이지입니다.
# 156 번째 페이지입니다.
# 157 번째 페이지입니다.
# 158 번째 페이지입니다.
# 159 번째 페이지입니다.
# 160 번째 페이지입니다.
# 161 번째 페이지입니다.
# 162 번째 페이지입니다.
# 163 번째 페이지입니다.
# 164 번째 페이지입니다.
# 165 번째 페이지입니다.
# 166 번째 페이지입니다.
# 167 번째 페이지입니다.
# 168 번째 페이지입니다.
# 169 번째 페이지입니다.
# 170 번째 페이지입니다.
# 171 번째 페이지입니다.
# 172 번째 페이지입니다.
# 173 번째 페이지입니다.
# 174 번째 페이지입니다.
# 175 번째 페이지입니다.
# 176 번째 페이지입니다.
# 177 번째 페이지입니다.
# 178 번째 페이지입니다.
# 179 번째 페이지입니다.
# 180 번째 페이지입니다.
# 181 번째 페이지입니다.
# 182 번째 페이지입니다.
# 183 번째 페이지입니다.
# 184 번째 페이지입니다.
# 185 번째 페이지입니다.
# 186 번째 페이지입니다.
# 187 번째 페이지입니다.
# 188 번째 페이지입니다.
# 189 번째 페이지입니다.
# 190 번째 페이지입니다.
# 191 번째 페이지입니다.
# 192 번째 페이지입니다.
# 193 번째 페이지입니다.
# 194 번째 페이지입니다.
# 195 번째 페이지입니다.
# 196 번째 페이지입니다.
# 197 번째 페이지입니다.
# 198 번째 페이지입니다.
# 199 번째 페이지입니다.
# 200 번째 페이지입니다.
# 201 번째 페이지입니다.
# 202 번째 페이지입니다.
# 203 번째 페이지입니다.
# 204 번째 페이지입니다.
# 205 번째 페이지입니다.
# 206 번째 페이지입니다.
# 207 번째 페이지입니다.
# 208 번째 페이지입니다.
# 209 번째 페이지입니다.
# 210 번째 페이지입니다.
# 211 번째 페이지입니다.
# 212 번째 페이지입니다.
# 213 번째 페이지입니다.
# 214 번째 페이지입니다.
# 215 번째 페이지입니다.
# 216 번째 페이지입니다.
# 217 번째 페이지입니다.
# 218 번째 페이지입니다.
# 219 번째 페이지입니다.
# 220 번째 페이지입니다.
# 221 번째 페이지입니다.
# 222 번째 페이지입니다.
# 223 번째 페이지입니다.
# 224 번째 페이지입니다.
# 225 번째 페이지입니다.
# 226 번째 페이지입니다.
# 227 번째 페이지입니다.
# 228 번째 페이지입니다.
# 229 번째 페이지입니다.
# 230 번째 페이지입니다.
# 231 번째 페이지입니다.
# 232 번째 페이지입니다.
# 233 번째 페이지입니다.
# 234 번째 페이지입니다.
# 235 번째 페이지입니다.
# 236 번째 페이지입니다.
# 237 번째 페이지입니다.
# 238 번째 페이지입니다.
# 239 번째 페이지입니다.
# 240 번째 페이지입니다.
# 241 번째 페이지입니다.
# 242 번째 페이지입니다.
# 243 번째 페이지입니다.
# 244 번째 페이지입니다.
# 245 번째 페이지입니다.
# 246 번째 페이지입니다.
# 247 번째 페이지입니다.
# 248 번째 페이지입니다.
# 249 번째 페이지입니다.
# 250 번째 페이지입니다.
# 251 번째 페이지입니다.
# 252 번째 페이지입니다.
# 253 번째 페이지입니다.
# 254 번째 페이지입니다.
# 255 번째 페이지입니다.
# 256 번째 페이지입니다.
# 257 번째 페이지입니다.
# 258 번째 페이지입니다.
# 259 번째 페이지입니다.
# 260 번째 페이지입니다.
# 261 번째 페이지입니다.
# 262 번째 페이지입니다.
# 263 번째 페이지입니다.
# 264 번째 페이지입니다.
# 265 번째 페이지입니다.
# 266 번째 페이지입니다.
# 267 번째 페이지입니다.
# 268 번째 페이지입니다.
# 269 번째 페이지입니다.
# 270 번째 페이지입니다.
# 271 번째 페이지입니다.
# 272 번째 페이지입니다.
# 273 번째 페이지입니다.
# 274 번째 페이지입니다.
# 275 번째 페이지입니다.
# 276 번째 페이지입니다.
# 277 번째 페이지입니다.
# 278 번째 페이지입니다.
# 279 번째 페이지입니다.
# 280 번째 페이지입니다.
# 281 번째 페이지입니다.
# 282 번째 페이지입니다.
# 283 번째 페이지입니다.
# 284 번째 페이지입니다.
# 285 번째 페이지입니다.
# 286 번째 페이지입니다.
# 287 번째 페이지입니다.
# 288 번째 페이지입니다.
# 289 번째 페이지입니다.
# 290 번째 페이지입니다.
# 291 번째 페이지입니다.
# 292 번째 페이지입니다.
# 293 번째 페이지입니다.
# 294 번째 페이지입니다.
# 295 번째 페이지입니다.
# 296 번째 페이지입니다.
# 297 번째 페이지입니다.
# 298 번째 페이지입니다.
# 299 번째 페이지입니다.
# 300 번째 페이지입니다.
# 301 번째 페이지입니다.
# 302 번째 페이지입니다.
# 303 번째 페이지입니다.
# 304 번째 페이지입니다.
# 305 번째 페이지입니다.
# 306 번째 페이지입니다.
# 307 번째 페이지입니다.
# 308 번째 페이지입니다.
# 리뷰수 :  4605 수집된 리뷰수 :  4605

# %%
url_open... stout 맥주 데이터를 수집합니다..
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
연속된 오류로 다음 맥주로 넘어갑니다...
url_open... dry finish 맥주 데이터를 수집합니다.

# %%
url_open... Hoegarden 맥주 데이터를 수집합니다..
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
오류 발생.. 다시 시작합니다.
연속된 오류로 다음 맥주로 넘어갑니다...
